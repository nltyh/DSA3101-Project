# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales_df = pd.read_csv("Orders Table.csv")
sales_df = sales_df.drop(['Unnamed: 0'], axis = 1)
# sales_df['Promotional Period'] = np.random.choice(a = [0,1], p = [0.8, 0.2], size=len(sales_df))
sales_df.head(10)
# sales_df.to_csv('Orders Table.csv')
# Out:
#    OrderID  ProductID  CustomerID       Order Date    Shipping Date  \
# 0    77202       5246       15795  1/31/2018 22:56   2/3/2018 22:56
# 1    75939       2362         860  1/13/2018 12:27  1/18/2018 12:27
# 2    75938      13940       76820  1/13/2018 12:06  1/17/2018 12:06
# 3    75937       1105       54886  1/13/2018 11:45  1/16/2018 11:45
# 4    75936       2987        6265  1/13/2018 11:24  1/15/2018 11:24
# 5    75935        285       82386  1/13/2018 11:03  1/19/2018 11:03
# 6    75934      10276       37194  1/13/2018 10:42  1/15/2018 10:42
# 7    75933       4506       87498  1/13/2018 10:21  1/15/2018 10:21
# 8    75932      16345       44131  1/13/2018 10:00  1/16/2018 10:00
# 9    75931       3558       60263   1/13/2018 9:39   1/15/2018 9:39
#
#    Actual days for shipping  Scheduled days for shipping  Late Delivery Risk  \
# 0                         3                            4                   0
# 1                         5                            4                   1
# 2                         4                            4                   0
# 3                         3                            4                   0
# 4                         2                            4                   0
# 5                         6                            4                   0
# 6                         2                            1                   1
# 7                         2                            1                   1
# 8                         3                            2                   1
# 9                         2                            1                   1
#
#    Discount Percentage  Returns  Promotional Period
# 0                 0.04        0                   0
# 1                 0.05        1                   1
# 2                 0.06        0                   0
# 3                 0.07        0                   1
# 4                 0.09        0                   1
# 5                 0.10        0                   1
# 6                 0.12        0                   1
# 7                 0.13        0                   1
# 8                 0.15        0                   1
# 9                 0.16        0                   1

# %%
products_df = pd.read_csv("Products Table.csv")
products_df = products_df.drop(['Unnamed: 0'], axis = 1)
products_df.head(10)
# Out:
#    ProductID                                       Product Name     Category  \
# 0          1  Wayona Nylon Braided USB to Lightning Fast Cha...  Electronics
# 1          2  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  Electronics
# 2          3  Sounce Fast Phone Charging Cable & Data Sync U...  Electronics
# 3          4  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...  Electronics
# 4          5  Portronics Konnect L 1.2M Fast Charging 3A 8 P...  Electronics
# 5          6  pTron Solero TB301 3A Type-C Data and Fast Cha...  Electronics
# 6          7  boAt Micro USB 55 Tangle-free, Sturdy Micro US...  Electronics
# 7          8             MI Usb Type-C Cable Smartphone (Black)  Electronics
# 8          9  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...  Electronics
# 9         10  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  Electronics
#
#    Price
# 0  13.19
# 1   4.19
# 2  22.79
# 3   8.39
# 4   4.79
# 5  12.00
# 6   5.99
# 7   3.59
# 8  11.99
# 9   3.59

# %%
# join on Product ID
sales_df = sales_df.set_index('ProductID')
products_df = products_df.set_index('ProductID')
joined_df = sales_df.join(products_df, lsuffix="_sales", rsuffix="_products")
joined_df.tail(10)
# Out:
#            OrderID  CustomerID       Order Date    Shipping Date  \
# ProductID
# 17209        26052       55383   1/16/2016 6:49   1/19/2016 6:49
# 14322        26052       21015   1/16/2016 6:49   1/19/2016 6:49
# 2456         26051       36367   1/16/2016 6:28   1/18/2016 6:28
# 12526        26050       97715   1/16/2016 6:07   1/22/2016 6:07
# 20291        26047       18866   1/16/2016 5:04   1/19/2016 5:04
# 13370        26043       53374   1/16/2016 3:40   1/20/2016 3:40
# 3246         26037       91268   1/16/2016 1:34   1/19/2016 1:34
# 8222         26024       59589  1/15/2016 21:00  1/20/2016 21:00
# 275          26022       10920  1/15/2016 20:18  1/18/2016 20:18
# 8604         26018       80878  1/15/2016 18:54  1/19/2016 18:54
#
#            Actual days for shipping  Scheduled days for shipping  \
# ProductID
# 17209                             3                            4
# 14322                             3                            4
# 2456                              2                            2
# 12526                             6                            4
# 20291                             3                            4
# 13370                             4                            4
# 3246                              3                            2
# 8222                              5                            4
# 275                               3                            4
# 8604                              4                            4
#
#            Late Delivery Risk  Discount Percentage  Returns  \
# ProductID
# 17209                       0                 0.16        1
# 14322                       0                 0.17        0
# 2456                        0                 0.18        0
# 12526                       1                 0.20        0
# 20291                       0                 0.25        0
# 13370                       0                 0.00        0
# 3246                        1                 0.01        0
# 8222                        1                 0.02        0
# 275                         0                 0.03        0
# 8604                        0                 0.04        0
#
#            Promotional Period  \
# ProductID
# 17209                       1
# 14322                       1
# 2456                        0
# 12526                       0
# 20291                       0
# 13370                       0
# 3246                        0
# 8222                        1
# 275                         0
# 8604                        0
#
#                                                 Product Name     Category  \
# ProductID
# 17209      DVKA Creations Women's Satin Solid Above The K...     Clothing
# 14322      CUPID Women's Cotton Plus Size Plain Half Slee...     Clothing
# 2456       EthnicJunction Women's Kanchipuram Silk Woven ...     Clothing
# 12526      ARTIBETTER 1pc Blue Light Blocking Glasses Ret...     Clothing
# 20291      Navya Diseno Present Banarasi Soft Lichi Silk ...     Clothing
# 13370      RIVER by Rajdeep Ranawat Premium Designer Wome...     Clothing
# 3246       Flyer stole / scarf for girl / ladies Colour- ...     Clothing
# 8222       TIGYWIGY Women's Satin Plain/Solid Top and Pyj...     Clothing
# 275        Airtel Digital TV HD Set Top Box with 1 Month ...  Electronics
# 8604       Kanha exports Woman Silk Kimono, Vintage Kimon...     Clothing
#
#            Price
# ProductID
# 17209       8.39
# 14322      17.94
# 2456       25.91
# 12526      24.00
# 20291      35.99
# 13370      33.59
# 3246       14.39
# 8222       17.99
# 275        27.59
# 8604       19.19

# %%
### EDA
df = joined_df

# split Order Date column into Date and Time columns
df[['Order Date', 'Order Time']] = df['Order Date'].str.split(' ', expand=True)

# convert Date column to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')

# extract month from Date
df['Month'] = df['Order Date'].dt.strftime('%b')

# drop day and time from Order Date column
df['Year-Month'] = df['Order Date'].dt.strftime('%Y-%m')

# drop unused columns
df = df.drop(['CustomerID', 'OrderID'], axis = 1)

# normalise Sales column
# df['log_sales'] = np.log(df['Sales'])
# df['scaled_sales'] = np.log(df['Sales'] / df['Product Price'])

# sort by date
df = df.sort_values('Order Date')

df.head(10)
# Out:
#           Order Date   Shipping Date  Actual days for shipping  \
# ProductID
# 6598      2015-01-01  1/3/2015 12:15                         2
# 1282      2015-01-01   1/4/2015 3:51                         3
# 14813     2015-01-01   1/4/2015 3:51                         3
# 7742      2015-01-01  1/7/2015 17:10                         6
# 10556     2015-01-01  1/7/2015 15:24                         6
# 4894      2015-01-01  1/3/2015 14:42                         2
# 11945     2015-01-01  1/4/2015 19:37                         3
# 5523      2015-01-01   1/7/2015 1:24                         6
# 17383     2015-01-01  1/3/2015 22:04                         2
# 8889      2015-01-01  1/6/2015 20:19                         5
#
#            Scheduled days for shipping  Late Delivery Risk  \
# ProductID
# 6598                                 2                   0
# 1282                                 4                   0
# 14813                                4                   0
# 7742                                 4                   0
# 10556                                4                   1
# 4894                                 1                   1
# 11945                                4                   0
# 5523                                 4                   1
# 17383                                1                   1
# 8889                                 4                   1
#
#            Discount Percentage  Returns  Promotional Period  \
# ProductID
# 6598                      0.06        0                   0
# 1282                      0.02        0                   0
# 14813                     0.07        0                   1
# 7742                      0.03        0                   1
# 10556                     0.16        0                   1
# 4894                      0.03        0                   0
# 11945                     0.25        0                   1
# 5523                      0.16        0                   0
# 17383                     0.16        1                   0
# 8889                      0.15        0                   0
#
#                                                 Product Name         Category  \
# ProductID
# 6598       Rock Paper Scissors Premium Flare Gym Pants Hi...         Clothing
# 1282       Proven® Copper + Mineral RO+UV+UF 10 to 12 Lit...  Home Appliances
# 14813      ANNI DESIGNER Women's Cotton Blend Printed Ana...         Clothing
# 7742       Pratham Blue Women's Sequins Georgette Fancy S...         Clothing
# 10556      SHAUN Women's Regular Fit Cotton Blend Track Pant         Clothing
# 4894       Pujia Mills Women's Heavy Silver Jari Thread R...         Clothing
# 11945      Coblue by Rupa 100% Cotton Panties for Women (...         Clothing
# 5523       YOUSTYLO - YOU ARE PRIORITY Men's Women's Slou...         Clothing
# 17383      WoodenTant Women Handloom Checkered pure Cotto...         Clothing
# 8889       Whitewhale Men Women Summer Loose Baggy Hippie...         Clothing
#
#             Price Order Time Month Year-Month
# ProductID
# 6598        20.99      12:15   Jan    2015-01
# 1282       239.88       3:51   Jan    2015-01
# 14813       31.19       3:51   Jan    2015-01
# 7742        47.99      17:10   Jan    2015-01
# 10556       11.99      15:24   Jan    2015-01
# 4894        36.00      14:42   Jan    2015-01
# 11945        4.79      19:37   Jan    2015-01
# 5523        11.99       1:24   Jan    2015-01
# 17383       26.40      22:04   Jan    2015-01
# 8889        11.99      20:19   Jan    2015-01

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df['Month'] = pd.Categorical(df['Month'], categories=months, ordered=True)
df_month = df.sort_values(by='Month')

# %%
category_sizes = df.groupby('Category').size()
category_sizes.plot(kind = 'bar')

plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Data available for each category")
plt.show()

# %%
category_sales = df.groupby('Category')['Price'].sum() / 1e6

category_sales.plot(kind = 'bar')

plt.xlabel("Category")
plt.ylabel("Sales (million)")
plt.title("Categorical Sales")
plt.show()

# %%
month_sizes = df_month.groupby('Month').size()

month_sizes.plot(kind = 'bar')

plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Monthly data available")
plt.show()
# Out:
# C:\Users\kahsu\AppData\Local\Temp\ipykernel_34868\557940995.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   month_sizes = df_month.groupby('Month').size()

# %%
month_sales = df_month.groupby('Month')['Price'].sum() / 1e6

month_sales.plot(kind = 'bar')

plt.xlabel("Month")
plt.ylabel("Sales (million)")
plt.title("Monthly Sales")
plt.show()
# Out:
# C:\Users\kahsu\AppData\Local\Temp\ipykernel_34868\322471454.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   month_sales = df_month.groupby('Month')['Price'].sum() / 1e6

# %%
date_sizes = df.groupby('Year-Month').size()
date_sizes.plot(kind = 'bar')

plt.xlabel("Year/Month")
plt.ylabel("Count")
plt.title("Data available for each Year/Month")
plt.show()

# %%
date_sales = df.groupby('Year-Month')['Price'].sum() / 1e6
date_sales.plot(kind = 'bar')

plt.xlabel("Year/Month")
plt.ylabel("Sales (million)")
plt.title("Sales over time")
plt.show()

# %%
categories = df['Category'].unique()

plt.figure(figsize=(10, 6))

for category in categories:
    # Filter the dataframe for each category
    product_data = df[df['Category'] == category]
        
    # Plot the sales over time for this category
    date_sales = product_data.groupby('Year-Month')['Price'].sum() / 1e6
    date_sales.plot(kind = 'line', label=f'{category}')

plt.xlabel('Date')
plt.ylabel('Sales (million)')
plt.title('Sales by Category over Time')
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
plt.figure(figsize=(10, 6))

for category in categories:
    # Filter the dataframe for each category
    product_data = df[df['Category'] == category]
    
    # Plot the sales over time for this product
    product_demand = np.log(product_data.groupby(['Year-Month']).size())
    product_demand.plot(kind = 'line', label=f'{category}')

plt.xlabel('Year/Month')
plt.ylabel('Demand (log)')
plt.title('Demand by Category over time')
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
'''
There seems to be higher demand during odd months and drops in demand during even months.
'''
# Out:
# '\nThere seems to be higher demand during odd months and drops in demand during even months.\n'

# %%
### Demand Forecasting

# %%
# ! pip install statsmodels

from statsmodels.tsa.seasonal import seasonal_decompose

result=seasonal_decompose(date_sizes, model='additive', period = 12).plot()
plt.xticks(rotation=90)
print('Close, additive decomposition, month frequency')
# Out:
# Close, additive decomposition, month frequency

# %%
plt.figure(figsize=(10, 6))

clothing_data = df[df['Category'] == 'Clothing']
clothing_data.groupby('Month').size().plot(kind = 'line')

plt.xlabel('Month')
plt.ylabel('Demand')
plt.title('Monthly Clothing Demand')
plt.show()
# Out:
# C:\Users\kahsu\AppData\Local\Temp\ipykernel_34868\1256915365.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   clothing_data.groupby('Month').size().plot(kind = 'line')

# %%
plt.figure(figsize=(10, 6))

electronic_data = df[df['Category'] == 'Electronics']
electronic_data.groupby('Month').size().plot(kind = 'line')

plt.xlabel('Month')
plt.ylabel('Demand')
plt.title('Monthly Electronics Demand')
plt.show()
# Out:
# C:\Users\kahsu\AppData\Local\Temp\ipykernel_34868\2150827907.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   electronic_data.groupby('Month').size().plot(kind = 'line')

# %%
plt.figure(figsize=(10, 6))

home_data = df[df['Category'] == 'Home Appliances']
home_data.groupby('Month').size().plot(kind = 'line')

plt.xlabel('Month')
plt.ylabel('Demand')
plt.title('Monthly Home Appliances Demand')
plt.show()
# Out:
# C:\Users\kahsu\AppData\Local\Temp\ipykernel_34868\2229869112.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   home_data.groupby('Month').size().plot(kind = 'line')

# %%
###  Create an inventory optimization algorithm to balance stock levels and costs.

# %%
# feature engineering
# df[df['Category'] == 'Clothing'].groupby('Month').size().mean() # 13105.083
# df[df['Category'] == 'Electronics'].groupby('Month').size().mean() # 665.6
# df[df['Category'] == 'Home Appliances'].groupby('Month').size().mean() # 308.083
df.groupby('Category')['Price'].mean()
# Out:
# Category
# Clothing           21.222797
# Electronics        75.294940
# Home Appliances    49.413121
# Name: Price, dtype: float64

# %%
# !pip install gurobipy --quiet
# !pip install rsome --quiet

from rsome import ro
from rsome import grb_solver as grb

model = ro.Model('Inventory')
x = model.dvar(3)

storage = 20000
# min_capacity = 0.6 # must use at least 60% of capacity
s = np.array([21.222797, 75.294940, 49.413121])  # average selling price per unit
o = np.array([10, 30, 20])  # order cost per unit
# b = np.array([2.5, 3.0, 4.0])  # backorder cost
h = np.array([2.0, 4.0, 3.0])  # holding cost
d = np.array([13105.1, 665.7, 308.1])  # average monthly demand

# revenue = sum(s @ x - o @ x)
# lost_sales = sum(b * (d - x))
# # holding_cost = h * (x - d)
# profit = revenue - lost_sales

model.max(s @ x - o @ x - h @ (x - d))
model.st(sum(x) >= 0)
model.st(x[i] >= d[i] for i in range(3))
# model.st(sum(x) >= storage * min_capacity)
model.st(sum(x) <= storage)

model.solve(grb)
# Out:
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0000s

# %%
model.get()
# Out:
# 430802.37033679994

# %%
x.get()
# Out:
# array([13105.1,  6586.8,   308.1])

# %%
# find top 10 products

product_data = df.groupby('Product Name').size()
product_data.sort_values().tail(10)
# Out:
# Product Name
# RAJESHWAR FASHION WITH RF Women's Pure Georgette Saree With Blouse Piece     92
# VERO MODA Women's Regular Fit T-Shirt                                        93
# Aurelia Women's Cotton Regular Kurta                                         94
# Selvia Women Dress                                                          101
# Anand Sarees Women's Saree With Blouse Piece                                105
# Aurelia Women Kurta                                                         111
# Levi's Women's 711 Skinny Fit Jeans                                         143
# Levi's Women's 710 Super Skinny Fit Jeans                                   183
# Levi's Women's Regular Fit T-Shirt                                          186
# Levi's Women T-Shirt                                                        228
# dtype: int64

# %%
# bottom 10 products

product_data.sort_values().head(10)
# Out:
# Product Name
# rytras Women's Rayon Printed A-Line Kurti                                                                                        1
# Van Heusen Women Lounge T-Shirt - 100% Supima Cotton - Round Neck, Short Sleeve, Superior Drape, Ultra Soft                      1
# Van Heusen Proactive Women T-Shirt - Polyamide Elastane - Anti Bacterial, Round Neck, Wicking_88402_Rose Wood_M                  1
# Crisko Fashion Women's Banarasi Silk Saree With Un-stitched Blouse Piece                                                         1
# SGF11 Women's Pure Georgette Full Sequins Work Saree With blouse piece                                                           1
# Janisa Fashion Women's Banarasi Jacquard Cotton Salwar Suit Dress Material Unstitiched (Free Size)                               1
# SRETAN Women's Assamese Machine-Weaving Poly Silk Mekhela Chador Saree                                                           1
# Rupa Jon Women's Cotton Panty (Pack of 5)(Colors May Vary) (105)                                                                 1
# Waanmayi Women's Kanchipuram Silk Saree With Blouse Piece (Mi_Lemon Silk_Yellow)                                                 1
# APSAMBR- 1 Inch 3 pcs Wide Plastic Headbands with Teeth Plain Hard Plastic Hairband Non-Slip Craft Headband Hoops for Wome...    1
# dtype: int64

# %%
from statsmodels.tsa.arima.model import ARIMA

date_sales = np.array(df.groupby('Year-Month')['Price'].sum() / 1e6)

train_size = int(len(date_sales) * 0.7)
train, test = date_sales[:train_size], date_sales[train_size:]

dates = df['Year-Month'].unique()
train_dates = dates[:train_size]
test_dates = dates[train_size:]

model = ARIMA(train, order=(1, 1, 1))  # can use (p, d, q) grid search to find the best parameters
arima_model = model.fit()

forecast = arima_model.forecast(steps=len(test))
plt.plot(train_dates, train, label='Train')
plt.plot(test_dates, test, label='Test')
plt.plot(test_dates, forecast, label='Forecast', color='red')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\kahsu\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
date_sales = np.array(np.log(df.groupby('Order Date').size()))

train_size = int(len(date_sales) * 0.7)
train, test = date_sales[:train_size], date_sales[train_size:]

dates = df['Order Date'].unique()
train_dates = dates[:train_size]
test_dates = dates[train_size:]

model = ARIMA(train, order=(1, 1, 1))  # can use (p, d, q) grid search to find the best parameters
arima_model = model.fit()

forecast = arima_model.forecast(steps=len(test))
plt.plot(train_dates, train, label='Train')
plt.plot(test_dates, test, label='Test')
plt.plot(test_dates, forecast, label='Forecast', color='red')
plt.xticks(rotation=90)
plt.show()
