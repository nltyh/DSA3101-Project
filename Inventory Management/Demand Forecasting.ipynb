# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales_df = pd.read_csv("Sales Table.csv")
sales_df = sales_df.drop(['Unnamed: 0'], axis = 1)
sales_df.head(10)
# Out:
#          Date  Number of units sold per week  Promotional Period  ProductID
# 0  05-02-2010                     1643690.90                   0        725
# 1  12-02-2010                     1641957.44                   1         37
# 2  19-02-2010                     1611968.17                   0        786
# 3  26-02-2010                     1409727.59                   0         44
# 4  05-03-2010                     1554806.68                   0        703
# 5  12-03-2010                     1439541.59                   1        134
# 6  19-03-2010                     1472515.79                   0         58
# 7  26-03-2010                     1404429.92                   0       1351
# 8  02-04-2010                     1594968.28                   0        725
# 9  09-04-2010                     1545418.53                   1         61

# %%
products_df = pd.read_csv("Product Table.csv")
products_df = products_df.drop(['Unnamed: 0'], axis = 1)
products_df.head(10)
# Out:
#    ProductID          Category                                   Product Name  \
# 0       1360    Sporting Goods                                   Smart watch
# 1        365            Cleats               Perfect Fitness Perfect Rip Deck
# 2        627     Shop By Sport  Under Armour Girls' Toddler Spine Surge Runni
# 3        502   Women's Apparel           Nike Men's Dri-FIT Victory Golf Polo
# 4        278       Electronics     Under Armour Men's Compression EV SL Slide
# 5        249      Boxing & MMA  Under Armour Women's Micro G Skulpt Running S
# 6        191  Cardio Equipment              Nike Men's Free 5.0+ Running Shoe
# 7        917          Trade-In  Glove It Women's Mod Oval 3-Zip Carry All Gol
# 8        828       Electronics  Bridgestone e6 Straight Distance NFL San Dieg
# 9        642     Shop By Sport        Columbia Men's PFG Anchor Tough T-Shirt
#
#    Product Price
# 0     327.750000
# 1      59.990002
# 2      39.990002
# 3      50.000000
# 4      44.990002
# 5      54.970001
# 6      99.989998
# 7      21.990000
# 8      31.990000
# 9      30.000000

# %%
# join on Product ID
sales_df = sales_df.set_index('ProductID')
products_df = products_df.set_index('ProductID')
joined_df = sales_df.join(products_df, lsuffix="_sales", rsuffix="_products")
joined_df.head(10)
# Out:
#                  Date  Number of units sold per week  Promotional Period  \
# ProductID
# 725        05-02-2010                     1643690.90                   0
# 37         12-02-2010                     1641957.44                   1
# 786        19-02-2010                     1611968.17                   0
# 44         26-02-2010                     1409727.59                   0
# 703        05-03-2010                     1554806.68                   0
# 134        12-03-2010                     1439541.59                   1
# 58         19-03-2010                     1472515.79                   0
# 1351       26-03-2010                     1404429.92                   0
# 725        02-04-2010                     1594968.28                   0
# 61         09-04-2010                     1545418.53                   1
#
#                       Category                                   Product Name  \
# ProductID
# 725                 Golf Shoes                 LIJA Women's Button Golf Dress
# 37         Baseball & Softball          adidas Kids' F5 Messi FG Soccer Cleat
# 786                Golf Gloves             TaylorMade 2014 Purelite Stand Bag
# 44         Baseball & Softball     adidas Men's F10 Messi TRX FG Soccer Cleat
# 703               Golf Apparel               Top Flite Women's 2014 XL Hybrid
# 134                     Hockey             Nike Women's Legend V-Neck T-Shirt
# 58                  Basketball  Diamondback Boys' Insight 24 Performance Hybr
# 1351                 Computers                                    Dell Laptop
# 725                 Golf Shoes                 LIJA Women's Button Golf Dress
# 61                  Basketball  Diamondback Girls' Clarity 24 Hybrid Bike 201
#
#            Product Price
# ProductID
# 725           108.000000
# 37             34.990002
# 786           179.990005
# 44             59.990002
# 703            19.990000
# 134            25.000000
# 58            299.989990
# 1351         1500.000000
# 725           108.000000
# 61            299.989990

# %%
### EDA
df = joined_df

# drop day from Date column
df['Date'] = df['Date'].str[3:]

# convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%m-%Y')

# extract month from Date
df['Month'] = df['Date'].dt.strftime('%b')

# Shorten column names
df = df.rename(columns={"Number of units sold per week": "Sales"})

# normalise Sales column
df['log_sales'] = np.log(df['Sales'])
df['scaled_sales'] = np.log(df['Sales'] / df['Product Price'])

# sort by date
df = df.sort_values('Date')

df
# Out:
#                 Date       Sales  Promotional Period          Category  \
# ProductID
# 725       2010-02-01  1643690.90                   0        Golf Shoes
# 93        2010-02-01   421642.19                   0          Lacrosse
# 403       2010-02-01   407204.86                   1    Men's Footwear
# 191       2010-02-01  1865097.27                   0  Cardio Equipment
# 564       2010-02-01  2124451.54                   0    Girls' Apparel
# ...              ...         ...                 ...               ...
# 502       2012-10-01   443557.65                   0   Women's Apparel
# 926       2012-10-01   410804.39                   0          Trade-In
# 1354      2012-10-01   424513.08                   1              DVDs
# 1357      2012-10-01  1847990.41                   1    Men's Clothing
# 278       2012-10-01  1508068.77                   0       Electronics
#
#                                             Product Name  Product Price Month  \
# ProductID
# 725                       LIJA Women's Button Golf Dress     108.000000   Feb
# 93                    Under Armour Men's Tech II T-Shirt      24.990000   Feb
# 403              Nike Men's CJ Elite 2 TD Football Cleat     129.990005   Feb
# 191                    Nike Men's Free 5.0+ Running Shoe      99.989998   Feb
# 564        Nike Men's Deutschland Weltmeister Winners Bl      30.000000   Feb
# ...                                                  ...            ...   ...
# 502                 Nike Men's Dri-FIT Victory Golf Polo      50.000000   Oct
# 926                         Glove It Imperial Golf Towel      15.990000   Oct
# 1354                                               DVDs      164.380005   Oct
# 1357                                     Men's gala suit     210.850006   Oct
# 278           Under Armour Men's Compression EV SL Slide      44.990002   Oct
#
#            log_sales  scaled_sales
# ProductID
# 725        14.312455      9.630324
# 93         12.951912      9.733437
# 403        12.917072      8.049614
# 191        14.438824      9.833754
# 564        14.569024     11.167827
# ...              ...           ...
# 502        13.002583      9.090560
# 926        12.925872     10.153909
# 1354       12.958698      7.856517
# 1357       14.429609      9.078462
# 278        14.226340     10.419900
#
# [490 rows x 9 columns]

# %%
df['count'] = df.groupby('Month')['Month'].transform('count')

plt.bar(df['Month'], df['count'])

plt.xlabel("Month")
plt.ylabel("Count")
plt.title("Monthly data available")
plt.show()

# %%
'''
lesser data in Novemeber and January could be an issue,
but according to monthly sales below, November has higher sales
and January's sales does not underperform
'''

# %%
plt.bar(df['Month'], df['Sales'] / 1e6, color ='maroon', 
        width = 0.4)

plt.xlabel("Month")
plt.ylabel("Sales (million)")
plt.title("Monthly Sales")
plt.show()

# %%
# before grouping by category

plt.scatter(df['Date'], df['log_sales'])
plt.ylabel("Sales (log)")
# Out:
# Text(0, 0.5, 'Sales (log)')

# %%
'''
November and December sees a surge in sales.
Other months stay relative constant at 2 million.
Makes sense to increase inventory levels during November and December.
'''

# %%
grouped_data = df.groupby(['Category'])['log_sales'].sum().reset_index()

# get top 10 performing categories
grouped_data.sort_values('log_sales', ascending = False).head(10)
# Out:
#              Category   log_sales
# 17        Electronics  576.494966
# 25        Golf Gloves  473.356213
# 31   Kids' Golf Clubs  470.503745
# 0         Accessories  389.907114
# 21     Girls' Apparel  308.297270
# 41  Strength Training  277.802108
# 26         Golf Shoes  268.690697
# 24         Golf Balls  252.681450
# 35   Men's Golf Clubs  236.126719
# 44           Trade-In  223.911589

# %%
# check if result above is skewed by product price

scaled_data = df.groupby(['Category'])['scaled_sales'].sum().reset_index()
scaled_data.sort_values('scaled_sales', ascending = False).head(10)

# top 10 categories seem to remain intact!
# Out:
#              Category  scaled_sales
# 17        Electronics    427.295417
# 25        Golf Gloves    311.772853
# 0         Accessories    299.789793
# 31   Kids' Golf Clubs    297.045315
# 21     Girls' Apparel    231.132768
# 24         Golf Balls    200.993046
# 26         Golf Shoes    182.200236
# 44           Trade-In    169.718679
# 35   Men's Golf Clubs    154.066231
# 41  Strength Training    148.096424

# %%
# do the same for bottom 10 performing categories
grouped_data.sort_values('log_sales').head(10)
# Out:
#                 Category  log_sales
# 15                Crafts  13.118675
# 1        As Seen on  TV!  27.129780
# 37          Pet Supplies  27.143706
# 27     Health and Beauty  28.684740
# 36                 Music  28.732589
# 30  Indoor/Outdoor Games  28.889369
# 23     Golf Bags & Carts  41.590916
# 43                  Toys  41.657600
# 2                  Baby   41.792584
# 11   Children's Clothing  41.808313

# %%
scaled_data.sort_values('scaled_sales').head(10)
# Out:
#                 Category  scaled_sales
# 15                Crafts      6.984237
# 27     Health and Beauty     17.324122
# 36                 Music     17.606232
# 1        As Seen on  TV!     17.919640
# 37          Pet Supplies     18.272571
# 30  Indoor/Outdoor Games     21.066123
# 11   Children's Clothing     24.174265
# 23     Golf Bags & Carts     26.183697
# 2                  Baby      29.555907
# 20                Garden     29.562658

# %%
'''
These results can inform decision making of inventory levels for top 10 and worst 10 catergories.
'''

# %%
categories = df['Category'].unique()

plt.figure(figsize=(10, 6))

for category in categories:
    # Filter the dataframe for each category
    product_data = df[df['Category'] == category]
        
    # Plot the sales over time for this category
    plt.plot(product_data['Date'], product_data['log_sales'], label=f'{category}')

plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales by Category over Time')
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
plt.figure(figsize=(10, 6))

for category in categories:
    # Filter the dataframe for each category
    product_data = df[df['Category'] == category]
        
    # Plot the sales over time for this category
    plt.bar(product_data['Month'], product_data['log_sales'], label=f'{category}')

plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales by Category')
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
df.groupby('Category').count()
# Out:
#                       Date  Sales  Promotional Period  Product Name  \
# Category
# Accessories             28     28                  28            28
# As Seen on  TV!          2      2                   2             2
# Baby                     3      3                   3             3
# Baseball & Softball     14     14                  14            14
# Basketball               7      7                   7             7
# Books                    7      7                   7             7
# Boxing & MMA             8      8                   8             8
# CDs                      3      3                   3             3
# Cameras                  5      5                   5             5
# Camping & Hiking         4      4                   4             4
# Cardio Equipment        10     10                  10            10
# Children's Clothing      3      3                   3             3
# Cleats                  12     12                  12            12
# Computers                5      5                   5             5
# Consumer Electronics     5      5                   5             5
# Crafts                   1      1                   1             1
# DVDs                     4      4                   4             4
# Electronics             41     41                  41            41
# Fishing                  7      7                   7             7
# Fitness Accessories     11     11                  11            11
# Garden                   4      4                   4             4
# Girls' Apparel          22     22                  22            22
# Golf Apparel            11     11                  11            11
# Golf Bags & Carts        3      3                   3             3
# Golf Balls              18     18                  18            18
# Golf Gloves             34     34                  34            34
# Golf Shoes              19     19                  19            19
# Health and Beauty        2      2                   2             2
# Hockey                  11     11                  11            11
# Hunting & Shooting       8      8                   8             8
# Indoor/Outdoor Games     2      2                   2             2
# Kids' Golf Clubs        33     33                  33            33
# Lacrosse                 5      5                   5             5
# Men's Clothing           7      7                   7             7
# Men's Footwear           4      4                   4             4
# Men's Golf Clubs        17     17                  17            17
# Music                    2      2                   2             2
# Pet Supplies             2      2                   2             2
# Shop By Sport           11     11                  11            11
# Soccer                  10     10                  10            10
# Sporting Goods           6      6                   6             6
# Strength Training       20     20                  20            20
# Tennis & Racquet         5      5                   5             5
# Toys                     3      3                   3             3
# Trade-In                16     16                  16            16
# Video Games              5      5                   5             5
# Water Sports             9      9                   9             9
# Women's Apparel          5      5                   5             5
# Women's Clothing         5      5                   5             5
# Women's Golf Clubs      11     11                  11            11
#
#                       Product Price  Month  log_sales  scaled_sales  count
# Category
# Accessories                      28     28         28            28     28
# As Seen on  TV!                   2      2          2             2      2
# Baby                              3      3          3             3      3
# Baseball & Softball              14     14         14            14     14
# Basketball                        7      7          7             7      7
# Books                             7      7          7             7      7
# Boxing & MMA                      8      8          8             8      8
# CDs                               3      3          3             3      3
# Cameras                           5      5          5             5      5
# Camping & Hiking                  4      4          4             4      4
# Cardio Equipment                 10     10         10            10     10
# Children's Clothing               3      3          3             3      3
# Cleats                           12     12         12            12     12
# Computers                         5      5          5             5      5
# Consumer Electronics              5      5          5             5      5
# Crafts                            1      1          1             1      1
# DVDs                              4      4          4             4      4
# Electronics                      41     41         41            41     41
# Fishing                           7      7          7             7      7
# Fitness Accessories              11     11         11            11     11
# Garden                            4      4          4             4      4
# Girls' Apparel                   22     22         22            22     22
# Golf Apparel                     11     11         11            11     11
# Golf Bags & Carts                 3      3          3             3      3
# Golf Balls                       18     18         18            18     18
# Golf Gloves                      34     34         34            34     34
# Golf Shoes                       19     19         19            19     19
# Health and Beauty                 2      2          2             2      2
# Hockey                           11     11         11            11     11
# Hunting & Shooting                8      8          8             8      8
# Indoor/Outdoor Games              2      2          2             2      2
# Kids' Golf Clubs                 33     33         33            33     33
# Lacrosse                          5      5          5             5      5
# Men's Clothing                    7      7          7             7      7
# Men's Footwear                    4      4          4             4      4
# Men's Golf Clubs                 17     17         17            17     17
# Music                             2      2          2             2      2
# Pet Supplies                      2      2          2             2      2
# Shop By Sport                    11     11         11            11     11
# Soccer                           10     10         10            10     10
# Sporting Goods                    6      6          6             6      6
# Strength Training                20     20         20            20     20
# Tennis & Racquet                  5      5          5             5      5
# Toys                              3      3          3             3      3
# Trade-In                         16     16         16            16     16
# Video Games                       5      5          5             5      5
# Water Sports                      9      9          9             9      9
# Women's Apparel                   5      5          5             5      5
# Women's Clothing                  5      5          5             5      5
# Women's Golf Clubs               11     11         11            11     11

# %%
df.shape
# Out:
# (490, 10)
